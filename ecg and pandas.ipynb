# %%
#Auto reloading everything imported with %aimport
# %load_ext autoreload
# %autoreload 1

#For scientific computing
from pylab import *
import numpy as np
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame
#To read data files
import json
import gzip
# %aimport reader
from datetime import datetime, date, time, timedelta
# Out:
# /home/pim/.local/lib/python2.7/site-packages/pytz/__init__.py:35: UserWarning: Module argparse was already imported from /usr/lib64/python2.7/argparse.pyc, but /home/pim/.local/lib/python2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream

# %%
#Inline plots
# %pylab --no-import-all inline
#Defaults for plotting
pylab.rcParams['figure.figsize'] = (15.0, 3.0)
pylab.rcParams['font.size'] = 14
pylab.rcParams['axes.titlesize'] = 20
pylab.rcParams['axes.labelsize'] = 16
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ###Import rr_interval into panda

# %%
kangaReader = reader.Reader(gzip.open('kanga.json.gz'))
# %time data = kangaReader.pandas(excludeSensors=["ecg (burst-mode)"])
# Out:
# 4.0
# CPU times: user 1min 16s, sys: 11.1 s, total: 1min 27s
# Wall time: 1min 28s

# %% [markdown]
# ###Some stats

# %%
data.describe()
# Out:
#        accelerometer_x  accelerometer_y  accelerometer_z      activity  \
# count   2810886.000000   2810886.000000   2810886.000000  87941.000000
# mean         -5.947472        -0.767924         1.316552      4.284202
# std           3.658090         4.480403         5.027745      4.788566
# min         -33.281000       -31.328000       -33.125000      0.000000
# 25%          -9.219000        -3.438000        -1.875000      0.000000
# 50%          -7.969000         0.234000         1.094000      2.000000
# 75%          -1.875000         1.875000         4.219000     11.000000
# max          18.125000        32.813000        12.422000     11.000000
#
#             battery  energy_expenditure_rate    heart_rate     impedance  \
# count  21970.000000             21951.000000  21938.000000  22028.000000
# mean      99.999727                83.773086     62.795697     80.210550
# std        0.028623                55.942804     17.799300     45.977285
# min       97.000000                62.000000     38.000000     16.000000
# 25%      100.000000                62.000000     49.000000     53.000000
# 50%      100.000000                62.000000     59.000000     65.000000
# 75%      100.000000                62.000000     73.000000    105.000000
# max      100.000000               614.000000    160.000000   1296.000000
#
#        memory_level   respiration   rr_interval  step_count_total  \
# count         21923  21997.000000  85645.000000      89677.000000
# mean             99     16.786925   1005.154930      29463.618754
# std               0      5.269748    347.398991       2381.252368
# min              99      4.000000    300.000000      27327.000000
# 25%              99     14.000000    760.000000      27395.000000
# 50%              99     16.000000   1000.000000      27622.000000
# 75%              99     19.000000   1202.000000      30951.000000
# max              99     42.000000   7668.000000      34859.000000
#
#         temperature
# count  21893.000000
# mean      34.881616
# std        1.152228
# min       31.500000
# 25%       34.320000
# 50%       34.959999
# 75%       35.899998
# max       36.559998

# %% [markdown]
# ##Some nice plots of heart rate

# %%
hr = data.heart_rate.dropna()
figure(figsize=(15,12))
subplot(3,1,1)
hr.plot()
xlabel("Time"); ylabel("Heart rate (bpm)"); title("Heart rate"); ylim((40,180));

subplot(3,1,2)
hr.resample("1min").plot()
xlabel("Time"); ylabel("Heart rate (bpm)"); title("Heart rate (1 min average)"); ylim((40,180));

subplot(3,1,3)
hr.resample("5min").plot()
xlabel("Time"); ylabel("Heart rate (bpm)"); title("Heart rate (5 min average)"); ylim((40,180));

# %%
figure()
data[['heart_rate', 'respiration']].resample("1min").plot()
xlabel("Time"); ylabel("Heart rate (bpm)"); title("Heart rate (5 min average)");

# %%
figure()
(60*1000.0 / data.rr_interval).hist(range=(0,200),bins=200, normed=True)
#hold(True)
#hr.hist(range=(0,200),bins=200, normed=True, alpha=0.8)
xlabel("Heart rate (bpm)"); ylabel("Relative frequency"); title("Heart rate histogram");xticks(range(0,200,10));legend(['rr', 'hr']);

# %% [markdown]
# ###Poincaré plot of rr intervals (scatter plot of subsequent intervals)
# Too many points to make something useful of this graph.

# %%
figure(figsize=(4,4))
scatter(data.rr_interval, data.rr_interval.shift());
xlabel("rr interval"); ylabel("subsequent rr interval"); title("Pointcare plot of rr intervals");

# %% [markdown]
# ###Panda show off with heartrate variation
# Shift the time series, calculate absolute difference and resample to every 5 min (how="mean")

# %%
figure(figsize=(15,4))
(abs(data.rr_interval - data.rr_interval.shift())).resample("5min").plot()
ylabel("Interval variation"); title("Heart rate variation (5 min averaged)");

# %% [markdown]
# ###Accelerometer

# %%
mydata=data.resample("1min");

# %%
mydata["magnitude"] = sqrt(mydata.accelerometer_x**2 + mydata.accelerometer_y**2 + mydata.accelerometer_z**2);

# %%
def upright(x):
    G=9.8
    return True if abs(degrees(arcsin(x/G))) > 30 else False
def posture(value):
    G=9.8
    print value
    x = value[mydata.accelerometer_x]
    y = value[mydata.accelerometer_y]
    z = value[mydata.accelerometer_z]
    
    angleFromLying = degrees(arcsin(x/G))
    if abs(angleFromLying) < 30:
        return "upright"
    else:
        #lying down
        angleFromSideWays = degrees(arcsin(z/G))
        if angleFromSideWays >= 45:
            return "lying on back"
        elif angleFromSideWays <= -45:
            return "lying on belly"
        else:
            #lying sideways
            if y >= 0:
                return "lying on right side"
            else:
                return "lying on left side"
mydata["upright"] = mydata.accelerometer_x.apply(upright);
#mydata["posture"] = mydata.apply(posture)

# %%
mydata.groupby(mydata.upright).describe()
# Out:
#                accelerometer_x  accelerometer_y  accelerometer_z    activity  \
# upright
# False   count       556.000000       556.000000       556.000000  556.000000
#         mean         -1.601377        -3.236284         3.470134    2.013883
#         std           0.597009         5.809730         6.123041    4.067036
#         min          -4.892586        -9.404294        -9.174124    0.000000
#         25%          -1.951217        -8.782081        -0.461082    0.000000
#         50%          -1.626273        -4.736420         3.898510    0.000000
#         75%          -1.266490         0.870483         8.931948    0.000000
#         max          -0.409632         9.675333        10.195433   11.000000
# True    count       888.000000       888.000000       888.000000  886.000000
#         mean         -8.714960         0.806002        -0.057103    5.733657
#         std           0.802732         2.007208         3.181618    3.938561
#         min          -9.651576        -5.259061        -7.423624    0.000000
#         25%          -9.281600        -0.243077        -2.504111    2.000000
#         50%          -9.020053         1.175580         0.057999    4.245902
#         75%          -8.260520         1.892403         2.496118   10.669818
#         max          -5.050659         6.758478         7.239552   11.000000
#
#                   battery  energy_expenditure_rate  heart_rate   impedance  \
# upright
# False   count  556.000000               556.000000  556.000000  556.000000
#         mean    99.999326                63.873141   48.414450   81.145455
#         std      0.015904                 9.035009    7.185022   52.626164
#         min     99.625000                62.000000   39.437500   20.875000
#         25%    100.000000                62.000000   43.600000   45.110417
#         50%    100.000000                62.000000   47.533333   58.966667
#         75%    100.000000                62.000000   50.750000  111.528125
#         max    100.000000               174.600000   89.266667  222.533333
# True    count  886.000000               886.000000  886.000000  886.000000
#         mean   100.000000                96.787472   72.026583   79.625592
#         std      0.000000                61.205399   14.710590   39.400324
#         min    100.000000                62.000000   48.000000   21.333333
#         25%    100.000000                62.000000   60.866667   57.466667
#         50%    100.000000                67.000000   69.533333   69.966667
#         75%    100.000000                99.792708   78.866667  103.100000
#         max    100.000000               373.866667  122.733333  658.666667
#
#                memory_level  respiration  rr_interval  step_count_total  \
# upright
# False   count           556   556.000000   556.000000        556.000000
#         mean             99    15.031627  1281.148740      27395.212230
#         std               0     2.717807   136.571519          1.472894
#         min              99     7.466667   750.961538      27388.000000
#         25%              99    13.408824  1210.210000      27395.000000
#         50%              99    14.733333  1275.382979      27395.000000
#         75%              99    16.133333  1380.864033      27395.000000
#         max              99    31.375000  1564.128205      27402.000000
# True    count           886   886.000000   886.000000        886.000000
#         mean             99    17.930921   913.373654      30850.261319
#         std               0     4.508114   147.293417       2163.458947
#         min              99     6.562500   506.118644      27327.000000
#         25%              99    14.866667   809.815392      30504.000000
#         50%              99    17.645833   909.929928      30858.000000
#         75%              99    20.466667  1015.377119      31091.000000
#         max              99    39.666667  1468.952381      34859.000000
#
#                temperature   magnitude upright
# upright
# False   count   556.000000  556.000000     593
#         mean     35.940536    9.813842       0
#         std       0.457282    0.490865       0
#         min      32.141333    5.814500   False
#         25%      35.730999    9.596424   False
#         50%      36.014874    9.917261       0
#         75%      36.258895   10.169686   False
#         max      36.559998   10.273751   False
# True    count   886.000000  888.000000     888
#         mean     34.204687    9.553987       1
#         std       0.934208    0.322748       0
#         min      31.501333    7.240554    True
#         25%      33.717906    9.525598       1
#         50%      34.448348    9.638456       1
#         75%      34.821207    9.720093       1
#         max      35.711332   10.012828    True

# %%
mydata.groupby(mydata.upright).mean()
# Out:
#          accelerometer_x  accelerometer_y  accelerometer_z  activity  \
# upright
# False          -1.601377        -3.236284         3.470134  2.013883
# True           -8.714960         0.806002        -0.057103  5.733657
#
#             battery  energy_expenditure_rate  heart_rate  impedance  \
# upright
# False     99.999326                63.873141   48.414450  81.145455
# True     100.000000                96.787472   72.026583  79.625592
#
#          memory_level  respiration  rr_interval  step_count_total  \
# upright
# False              99    15.031627  1281.148740      27395.212230
# True               99    17.930921   913.373654      30850.261319
#
#          temperature  magnitude upright
# upright
# False      35.940536   9.813842   False
# True       34.204687   9.553987    True

# %%
d = mydata
d.groupby(d.upright).boxplot();

# %% [markdown]
# ###Scratch pad

# %%
#Some magic to make an interactive plot
#%pylab gtk
#plot(range(10));

# %%
#%pylab inline

# %%
#d1 = datetime.now()
#df1=DataFrame([{"x":1,"y":2,"z":3}], index=[d1])
#df2=DataFrame([{"u":3}], index=[d1])

# %%
#%time data.to_csv("kanga.csv")
#%time data2=pd.read_csv("kanga.csv", parse_dates=True)
