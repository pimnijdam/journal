# %%
from mpl_toolkits.basemap import Basemap
from geopy.geocoders import OpenMapQuest
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-e6b29fae8787> in <module>()
# ----> 1 from mpl_toolkits.basemap import Basemap
#       2 from geopy.geocoders import OpenMapQuest
#
# ImportError: No module named 'mpl_toolkits.basemap'

# %%
geocoder = OpenMapQuest()
address, (lat, lon) = geocoder.geocode("Delft, Netherlands",exactly_one=True)
# Out:
# /home/pim/.local/lib/python2.7/site-packages/geopy/geocoders/openmapquest.py:52: UserWarning: Didn't find exactly one resource!(Found 9.), use exactly_one=False
#
#   "(Found %d.), use exactly_one=False\n" % len(resources)

# %%
m = Basemap(resolution='c')
m.drawcoastlines()
m.drawcountries()
